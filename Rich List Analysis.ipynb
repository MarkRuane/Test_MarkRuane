# %% [markdown]
# To start we add all the package that I will need throughout this analysis

# %%
import pandas as pd
import numpy as np
import scipy
import scipy.stats as stats
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# First of all I import my CSV file of Forbe Billionaires I sourced from Kaggle

# %%
richlist=pd.read_csv("forbes_2022_billionaires.csv")

# %% [markdown]
# Printing the head of the data to make sure we data is usable and what we expcted

# %%
richlist.head()
# Out:
#    rank                personName   age  finalWorth  year  month  \
# 0     1                 Elon Musk  50.0    219000.0  2022      4
# 1     2                Jeff Bezos  58.0    171000.0  2022      4
# 2     3  Bernard Arnault & family  73.0    158000.0  2022      4
# 3     4                Bill Gates  66.0    129000.0  2022      4
# 4     5            Warren Buffett  91.0    118000.0  2022      4
#
#                 category              source        country       state  ...  \
# 0             Automotive       Tesla, SpaceX  United States       Texas  ...
# 1             Technology              Amazon  United States  Washington  ...
# 2       Fashion & Retail                LVMH         France         NaN  ...
# 3             Technology           Microsoft  United States  Washington  ...
# 4  Finance & Investments  Berkshire Hathaway  United States    Nebraska  ...
#
#                        organization selfMade gender   birthDate  \
# ...

# %%
richlist.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2668 entries, 0 to 2667
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   rank                  2668 non-null   int64
#  1   personName            2668 non-null   object
#  2   age                   2582 non-null   float64
#  3   finalWorth            2668 non-null   float64
#  4   year                  2668 non-null   int64
#  5   month                 2668 non-null   int64
#  6   category              2668 non-null   object
#  7   source                2668 non-null   object
#  8   country               2655 non-null   object
#  9   state                 748 non-null    object
#  10  city                  2624 non-null   object
#  11  countryOfCitizenship  2668 non-null   object
#  12  organization          352 non-null    object
#  13  selfMade              2668 non-null   bool
#  14  gender                2652 non-null   object
# ...

# %%
print(richlist.isna().sum())
# Out:
# rank                       0
# personName                 0
# age                       86
# finalWorth                 0
# year                       0
# month                      0
# category                   0
# source                     0
# country                   13
# state                   1920
# city                      44
# countryOfCitizenship       0
# organization            2316
# selfMade                   0
# gender                    16
# birthDate                 99
# title                   2267
# philanthropyScore       2272
# residenceMsa            2029
# numberOfSiblings        2541
# bio                        0
# about                   1106
# dtype: int64

# %% [markdown]
# Finding our which countries have the most Billionaires

# %%
richlist.groupby(['country']).count()['city'].sort_values(ascending=False)
# Out:
# country
# United States     748
# China             569
# India             159
# Germany           109
# United Kingdom     84
#                  ...
# Nepal               1
# Oman                1
# Algeria             1
# Andorra             0
# Bermuda             0
# Name: city, Length: 73, dtype: int64

# %%
richlist.groupby(['age']).count()['country'].sort_values(ascending=False)
# Out:
# age
# 57.0     82
# 59.0     82
# 58.0     81
# 54.0     78
# 56.0     76
#          ..
# 27.0      2
# 29.0      2
# 28.0      2
# 100.0     1
# 19.0      0
# Name: country, Length: 76, dtype: int64

# %% [markdown]
# Who was the most generous to charity, based off Philanthropy Score

# %%
richlist.sort_values("philanthropyScore", ascending=False).head()
# Out:
#       rank        personName   age  finalWorth  year  month  \
# 1389  1341        Ted Turner  83.0      2300.0  2022      4
# 905    883  T. Denny Sanford  86.0      3400.0  2022      4
# 4        5    Warren Buffett  91.0    118000.0  2022      4
# 872    851  Lynn Schusterman  83.0      3500.0  2022      4
# 215    214      Gordon Moore  93.0      9500.0  2022      4
#
#                    category                  source        country  \
# 1389  Media & Entertainment        cable television  United States
# 905   Finance & Investments   banking, credit cards  United States
# 4     Finance & Investments      Berkshire Hathaway  United States
# 872                  Energy  oil & gas, investments  United States
# 215              Technology                   Intel  United States
#
#              state  ...        organization selfMade gender   birthDate  \
# 1389       Georgia  ...                 NaN    False      M  1938-11-19
# ...
